# %% [markdown]
# <a href="https://colab.research.google.com/github/pb-roshith/prakiriti-finding-using-ann/blob/main/prakritifindingANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras

# %%
data = pd.read_csv('/content/Book_updated (2).csv')
data
# Out:
#    Prakruti type Body Frame  Body weight   Skin    Hair   Teeth   Eyes  \
# 0           Vata       Thin          Low    Dry     Dry     Big  Small
# 1          Pitha      Broad  Over Weight  Thick    Soft     Big  Thick
# 2           Vata      Broad  Over Weight  Thick    Soft  Strong  Small
# 3       Tridosha      Broad  Over Weight  Thick  Strong  Strong    Big
# 4          Pitha     Medium     Moderate   Soft    Soft  Strong  Thick
# ..           ...        ...          ...    ...     ...     ...    ...
# 94    Vata-Kapha      Broad  Over Weight  Thick     Dry  Strong  Small
# 95   Pitha-Kapha       Thin  Over Weight   Soft    Soft  Strong  Thick
# 96      Tridosha       Thin          Low  Thick     Dry     Big  Thick
# 97   Pitha-Kapha     Medium  Over Weight   Soft    Soft  Strong  Thick
# 98      Tridosha      Broad          Low  Thick     Dry     Big  Thick
#
#       Nails   Tongue Food Habits     Thirst  Bowl Physical Activities  \
# ...

# %%
data.head()
# Out:
#   Prakruti type Body Frame  Body weight   Skin    Hair   Teeth   Eyes  \
# 0          Vata       Thin          Low    Dry     Dry     Big  Small
# 1         Pitha      Broad  Over Weight  Thick    Soft     Big  Thick
# 2          Vata      Broad  Over Weight  Thick    Soft  Strong  Small
# 3      Tridosha      Broad  Over Weight  Thick  Strong  Strong    Big
# 4         Pitha     Medium     Moderate   Soft    Soft  Strong  Thick
#
#      Nails   Tongue Food Habits     Thirst  Bowl Physical Activities  \
# 0  Brittle  Cracked    Frequent   Variable   Dry         Very Active
# 1     Soft      Red   Excessive  Excessive  Soft            Moderate
# 2  Brittle  Cracked    Frequent   Variable   Dry         Very Active
# 3     Soft      Red   Excessive  Excessive  Soft            Moderate
# 4     Soft      Red   Excessive  Excessive  Soft            Moderate
#
#   Tolerance for Seasonal Weather Communication    Memory  \
# 0                Cold Intolerant    Less Vocal      SLow
# ...

# %%
data.tail()
# Out:
#    Prakruti type Body Frame  Body weight   Skin  Hair   Teeth   Eyes    Nails  \
# 94    Vata-Kapha      Broad  Over Weight  Thick   Dry  Strong  Small  Brittle
# 95   Pitha-Kapha       Thin  Over Weight   Soft  Soft  Strong  Thick     Soft
# 96      Tridosha       Thin          Low  Thick   Dry     Big  Thick     Soft
# 97   Pitha-Kapha     Medium  Over Weight   Soft  Soft  Strong  Thick     Soft
# 98      Tridosha      Broad          Low  Thick   Dry     Big  Thick     Soft
#
#    Tongue Food Habits    Thirst  Bowl Physical Activities  \
# 94  White    Frequent  Variable  Oily           Lethargic
# 95    Red   Excessive  Variable  Oily           Lethargic
# 96  White      Stable  Variable   Dry            Moderate
# 97    Red   Excessive  Variable  Oily           Lethargic
# 98  White      Stable  Variable   Dry            Moderate
#
#    Tolerance for Seasonal Weather Communication    Memory  \
# 94                Heat Intolerant     Talkative     Quick
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder()
lis=[['Prakruti type','Body Frame','Body weight','Skin','Hair','Teeth','Eyes','Nails','Tongue','Food Habits','Thirst','Bowl','Physical Activities','Tolerance for Seasonal Weather','Communication','Memory','Emotional Temperament','Pulse','Body Temperature']]
for i in lis:
    data[i]=encoder.fit_transform(data[i])

# %%
from sklearn.model_selection import train_test_split
x = data.iloc[:, 1:19].values
y = data.iloc[:, 0].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
x
# Out:
# array([[2., 0., 0., ..., 0., 1., 2.],
#        [0., 2., 2., ..., 0., 1., 0.],
#        [0., 2., 2., ..., 2., 0., 2.],
#        ...,
#        [2., 0., 2., ..., 2., 2., 1.],
#        [1., 2., 1., ..., 1., 1., 2.],
#        [0., 0., 2., ..., 2., 0., 1.]])

# %%
y
# Out:
# array([4., 1., 4., 3., 1., 4., 6., 5., 2., 3., 5., 4., 0., 1., 6., 2., 3.,
#        5., 1., 0., 4., 1., 0., 6., 5., 2., 3., 4., 1., 0., 6., 5., 2., 3.,
#        4., 1., 0., 6., 5., 2., 3., 4., 1., 0., 6., 5., 2., 3., 4., 1., 0.,
#        6., 5., 2., 3., 4., 1., 0., 6., 5., 2., 3., 4., 1., 0., 6., 5., 2.,
#        3., 4., 1., 0., 6., 5., 2., 3., 4., 1., 0., 6., 5., 2., 3., 4., 1.,
#        0., 6., 5., 2., 3., 4., 1., 0., 6., 5., 2., 3., 2., 3.])

# %%
x_train
# Out:
# array([[0., 2., 2., ..., 1., 2., 1.],
#        [2., 1., 1., ..., 2., 0., 0.],
#        [0., 2., 2., ..., 2., 0., 2.],
#        ...,
#        [0., 2., 2., ..., 1., 0., 2.],
#        [1., 2., 0., ..., 1., 1., 0.],
#        [2., 1., 0., ..., 2., 1., 0.]])

# %%
x_train[60]
# Out:
# array([1., 1., 1., 2., 1., 2., 1., 0., 2., 1., 2., 0., 2., 0., 0., 2., 2.,
#        1.])

# %%
y_train
# Out:
# array([0., 4., 3., 0., 5., 4., 6., 3., 3., 4., 2., 5., 3., 3., 6., 4., 1.,
#        1., 1., 2., 1., 3., 1., 4., 1., 2., 5., 3., 5., 4., 4., 5., 4., 4.,
#        1., 0., 4., 1., 6., 5., 5., 5., 5., 0., 6., 0., 2., 1., 6., 2., 0.,
#        0., 1., 3., 2., 4., 4., 6., 6., 1., 2., 6., 2., 2., 2., 6., 6., 0.,
#        1., 5., 0., 1., 4., 3., 2., 2., 0., 3., 6.])

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=8, activation='relu'))
model.add(tf.keras.layers.Dense(units=8, activation='relu'))
model.add(tf.keras.layers.Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(x_train, y_train, batch_size=12, epochs=1000, verbose=1)
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 1s 3ms/step - loss: 18.2727
# Epoch 2/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 16.4357
# Epoch 3/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.0406
# Epoch 4/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 13.9692
# Epoch 5/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.1929
# Epoch 6/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.4422
# Epoch 7/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 11.8145
# Epoch 8/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 11.1679
# Epoch 9/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 10.5007
# Epoch 10/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 9.8934
# Epoch 11/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 9.3099
# Epoch 12/1000
# ...

# %%
from sklearn.metrics import mean_squared_error
y_pred = model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 55ms/step

# %%
print(f"mean squared error : {mean_squared_error(y_pred, y_test)}")
# Out:
# mean squared error : 3.888495514627709

# %%
# 0 = kapha, 1= pitha, 2 = pitha-kapha 3 = tridosha, 4 = vata, 5 = vata-kapha, 6 = vata-pitha

# %%
pred = model.predict([[1., 1., 1., 2., 1., 2., 1., 0., 2., 1., 2., 0., 2., 0., 0., 2., 2., 1.]])
print(round(pred[0][0]))
# Out:
# 1/1 [==============================] - 0s 52ms/step
# 2
